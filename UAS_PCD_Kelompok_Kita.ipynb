# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.0/793.0 kB 10.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !scp '/content/drive/MyDrive/PACOD/data_uang.zip' '/content/data_uang.zip'

# !unzip '/content/data_uang.zip' -d '/content/'
# Out:
# Archive:  /content/data_uang.zip
#  extracting: /content/README.dataset.txt
#  extracting: /content/README.roboflow.txt
#  extracting: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/074331400_1545194154-uang5ribucov-1-_jpg.rf.e0e9c7cd4195c3da33acfddf51c6442a.jpg
#  extracting: /content/test/images/10000-Rupiah-back_jpg.rf.254b6a524f1220f38cd1bea41d5ff88e.jpg
#  extracting: /content/test/images/10000_Rupiah_jpg.rf.5c864389eef671244f6e83f4c442408c.jpg
#  extracting: /content/test/images/1134155_720-Copy_jpg.rf.75c4c7ef003ed1dd6e1341766e1cfc13.jpg
#  extracting: /content/test/images/134_jpg.rf.3e6a52bd62ca48da72c2cef6ad5691b7.jpg
#  extracting: /content/test/images/150_jpg.rf.44191d30c6d478352c9f3ecb02971ca9.jpg
#  extracting: /content/test/images/155_jpg.rf.f85edba71d20867806cc664450c07e40.jpg
#  extracting: /content/test/images/225_jpg.rf.3b4842cb9dff7cb60d934392595ce697.jpg
# ...

# %%
train_path_img = "./yolo_data/images/train/"
train_path_label = "./yolo_data/labels/train/"
val_path_img = "./yolo_data/images/val/"
val_path_label = "./yolo_data/labels/val/"
test_path = "./yolo_data/test"

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.3/78.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/content/data.yaml epochs=50 imgsz=640 batch=16 project=/content/drive/MyDrive/PACOD/uang_results name=duit_nano
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/PACOD/uang_results/duit_nano2/weights/best.pt conf=0.35 source=/content/test/images save=True
# Out:
# Ultralytics YOLOv8.2.42 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007598 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/31 /content/test/images/074331400_1545194154-uang5ribucov-1-_jpg.rf.e0e9c7cd4195c3da33acfddf51c6442a.jpg: 640x640 3 lima ribu rupiahs, 1 seribu rupiah, 11.3ms
# image 2/31 /content/test/images/10000-Rupiah-back_jpg.rf.254b6a524f1220f38cd1bea41d5ff88e.jpg: 640x640 4 sepuluh ribu rupiahs, 7.4ms
# image 3/31 /content/test/images/10000_Rupiah_jpg.rf.5c864389eef671244f6e83f4c442408c.jpg: 640x640 6 sepuluh ribu rupiahs, 7.4ms
# image 4/31 /content/test/images/1134155_720-Copy_jpg.rf.75c4c7ef003ed1dd6e1341766e1cfc13.jpg: 640x640 4 sepuluh ribu rupiahs, 1 seratus ribu rupiah, 7.4ms
# image 5/31 /content/test/images/134_jpg.rf.3e6a52bd62ca48da72c2cef6ad5691b7.jpg: 640x640 2 seratus ribu rupiahs, 7.7ms
# ...

# %%
# !cp -r /content/runs/detect/predict3 /content/drive/MyDrive/PACOD/output
